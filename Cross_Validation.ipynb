# %%
import preprocessingFuncts as pp
import numpy as np
import pandas as pd
from models import KmeansCF
from models import CF
from simModel import simiModel
from sklearn.naive_bayes import CategoricalNB
from sklearn.metrics import classification_report

modelname = ["KmeansCF('user')","CF('user')","CF('item')","simiModel('user')","CategoricalNB()"]
dicpath=['ml-100k\\u1.base','ml-100k\\u2.base','ml-100k\\u3.base','ml-100k\\u4.base','ml-100k\\u5.base']
dicpathtest=['ml-100k\\u1.test','ml-100k\\u2.test','ml-100k\\u3.test','ml-100k\\u4.test','ml-100k\\u5.test']

for i in range(0,len(dicpath)):
    print(f'Split : {i+1}')
    index=0
    mydatatest=pp.readRatingData(dicpathtest[i])
    testX, testY = mydatatest.loc[:, ['user_id',
                                    'item_id']], mydatatest.loc[:, 'rating']
    model = [KmeansCF('user'),CF('user'),CF('item'),simiModel('user')]  
    for j in model:
        print(f'Model: {modelname[index]}')
        tempmodel = j
        tempmodel.fit(dicpath[i])
        predY = tempmodel.predict(testX)
        print(classification_report(testY,predY))
        index+=1
    
    # print("going here")
    print(f'Model: {modelname[index]}')
    tempmodel = CategoricalNB()
    # print(dicpath[i])
    ratingData = pp.readRatingData(dicpath[i])
    # print(ratingData)
    xTrain, yTrain = ratingData.loc[:,['user_id','item_id']], ratingData.loc[:, 'rating']
    tempmodel.fit(xTrain, yTrain)
    # print(testX.index.values)
    predY = tempmodel.predict(testX)
    print(classification_report(testY, predY))
    del tempmodel
# Out:
# Split : 1
# Model: KmeansCF('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.37      0.02      0.04      1391
#            2       0.22      0.14      0.17      2192
#            3       0.31      0.44      0.36      5182
#            4       0.38      0.56      0.45      6778
#            5       0.43      0.11      0.17      4457
#
#     accuracy                           0.34     20000
#    macro avg       0.28      0.21      0.20     20000
# weighted avg       0.35      0.34      0.31     20000
#
# Model: CF('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.39      0.04      0.08      1391
#            2       0.26      0.17      0.21      2192
#            3       0.33      0.37      0.35      5182
#            4       0.40      0.47      0.43      6778
#            5       0.47      0.13      0.21      4457
#
#     accuracy                           0.31     20000
#    macro avg       0.31      0.20      0.21     20000
# weighted avg       0.38      0.31      0.31     20000
#
# Model: CF('item')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.02      0.00      0.00      1391
#            2       0.08      0.03      0.04      2192
#            3       0.26      0.20      0.23      5182
#            4       0.35      0.37      0.36      6778
#            5       0.24      0.11      0.15      4457
#
#     accuracy                           0.21     20000
#    macro avg       0.16      0.12      0.13     20000
# weighted avg       0.25      0.21      0.22     20000
#
# Model: simiModel('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.49      0.03      0.05      1391
#            2       0.23      0.14      0.18      2192
#            3       0.31      0.42      0.36      5182
#            4       0.38      0.58      0.46      6778
#            5       0.44      0.12      0.19      4457
#
#     accuracy                           0.35     20000
#    macro avg       0.31      0.22      0.21     20000
# weighted avg       0.37      0.35      0.31     20000
#
# Model: CategoricalNB()
#               precision    recall  f1-score   support
#
#            1       0.53      0.35      0.42      1391
#            2       0.28      0.11      0.15      2192
#            3       0.40      0.40      0.40      5182
#            4       0.43      0.58      0.50      6778
#            5       0.48      0.42      0.45      4457
#
#     accuracy                           0.43     20000
#    macro avg       0.42      0.37      0.39     20000
# weighted avg       0.43      0.43      0.42     20000
#
# Split : 2
# Model: KmeansCF('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.30      0.02      0.03      1257
#            2       0.23      0.16      0.19      2185
#            3       0.31      0.43      0.36      5334
#            4       0.38      0.54      0.45      6880
#            5       0.40      0.11      0.17      4344
#
#     accuracy                           0.34     20000
#    macro avg       0.27      0.21      0.20     20000
# weighted avg       0.35      0.34      0.31     20000
#
# Model: CF('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.32      0.04      0.08      1257
#            2       0.25      0.17      0.20      2185
#            3       0.34      0.39      0.36      5334
#            4       0.40      0.48      0.44      6880
#            5       0.45      0.14      0.21      4344
#
#     accuracy                           0.32     20000
#    macro avg       0.30      0.20      0.22     20000
# weighted avg       0.38      0.32      0.32     20000
#
# Model: CF('item')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.05      0.00      0.01      1257
#            2       0.10      0.03      0.05      2185
#            3       0.26      0.17      0.21      5334
#            4       0.35      0.32      0.34      6880
#            5       0.23      0.10      0.14      4344
#
#     accuracy                           0.18     20000
#    macro avg       0.17      0.11      0.12     20000
# weighted avg       0.25      0.18      0.21     20000
#
# Model: simiModel('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.39      0.02      0.04      1257
#            2       0.24      0.15      0.19      2185
#            3       0.33      0.42      0.37      5334
#            4       0.38      0.57      0.46      6880
#            5       0.40      0.12      0.19      4344
#
#     accuracy                           0.35     20000
#    macro avg       0.29      0.22      0.21     20000
# weighted avg       0.36      0.35      0.32     20000
#
# Model: CategoricalNB()
#               precision    recall  f1-score   support
#
#            1       0.50      0.33      0.40      1257
#            2       0.31      0.10      0.15      2185
#            3       0.41      0.41      0.41      5334
#            4       0.43      0.60      0.50      6880
#            5       0.48      0.41      0.44      4344
#
#     accuracy                           0.44     20000
#    macro avg       0.43      0.37      0.38     20000
# weighted avg       0.43      0.44      0.42     20000
#
# Split : 3
# Model: KmeansCF('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.36      0.03      0.05      1187
#            2       0.21      0.12      0.15      2220
#            3       0.32      0.42      0.36      5581
#            4       0.39      0.56      0.46      6931
#            5       0.39      0.11      0.17      4081
#
#     accuracy                           0.35     20000
#    macro avg       0.28      0.21      0.20     20000
# weighted avg       0.35      0.35      0.31     20000
#
# Model: CF('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.24      0.05      0.08      1187
#            2       0.24      0.16      0.19      2220
#            3       0.35      0.35      0.35      5581
#            4       0.40      0.48      0.44      6931
#            5       0.42      0.17      0.24      4081
#
#     accuracy                           0.32     20000
#    macro avg       0.28      0.20      0.22     20000
# weighted avg       0.36      0.32      0.32     20000
#
# Model: CF('item')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00      1187
#            2       0.08      0.02      0.03      2220
#            3       0.28      0.15      0.20      5581
#            4       0.35      0.28      0.31      6931
#            5       0.22      0.10      0.14      4081
#
#     accuracy                           0.16     20000
#    macro avg       0.16      0.09      0.11     20000
# weighted avg       0.25      0.16      0.19     20000
#
# Model: simiModel('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.34      0.03      0.05      1187
#            2       0.22      0.12      0.16      2220
#            3       0.33      0.42      0.37      5581
#            4       0.39      0.57      0.46      6931
#            5       0.38      0.12      0.19      4081
#
#     accuracy                           0.36     20000
#    macro avg       0.28      0.21      0.20     20000
# weighted avg       0.35      0.36      0.32     20000
#
# Model: CategoricalNB()
#               precision    recall  f1-score   support
#
#            1       0.47      0.26      0.34      1187
#            2       0.32      0.13      0.18      2220
#            3       0.41      0.43      0.42      5581
#            4       0.44      0.59      0.51      6931
#            5       0.49      0.41      0.44      4081
#
#     accuracy                           0.44     20000
#    macro avg       0.43      0.36      0.38     20000
# weighted avg       0.43      0.44      0.42     20000
#
# Split : 4
# Model: KmeansCF('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.31      0.02      0.04      1117
#            2       0.24      0.15      0.19      2396
#            3       0.33      0.43      0.37      5571
#            4       0.38      0.56      0.45      6765
#            5       0.40      0.12      0.18      4151
#
#     accuracy                           0.35     20000
#    macro avg       0.28      0.21      0.21     20000
# weighted avg       0.35      0.35      0.32     20000
#
# Model: CF('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.26      0.05      0.08      1117
#            2       0.28      0.17      0.21      2396
#            3       0.35      0.35      0.35      5571
#            4       0.39      0.47      0.43      6765
#            5       0.45      0.17      0.25      4151
#
#     accuracy                           0.31     20000
#    macro avg       0.29      0.20      0.22     20000
# weighted avg       0.37      0.31      0.32     20000
#
# Model: CF('item')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.03      0.00      0.00      1117
#            2       0.11      0.02      0.03      2396
#            3       0.28      0.11      0.16      5571
#            4       0.33      0.21      0.26      6765
#            5       0.23      0.08      0.12      4151
#
#     accuracy                           0.12     20000
#    macro avg       0.16      0.07      0.10     20000
# weighted avg       0.25      0.12      0.16     20000
#
# Model: simiModel('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.29      0.03      0.05      1117
#            2       0.24      0.14      0.18      2396
#            3       0.33      0.42      0.37      5571
#            4       0.38      0.57      0.46      6765
#            5       0.41      0.13      0.19      4151
#
#     accuracy                           0.35     20000
#    macro avg       0.28      0.21      0.21     20000
# weighted avg       0.35      0.35      0.32     20000
#
# Model: CategoricalNB()
#               precision    recall  f1-score   support
#
#            1       0.39      0.22      0.28      1117
#            2       0.33      0.13      0.19      2396
#            3       0.41      0.42      0.41      5571
#            4       0.43      0.59      0.50      6765
#            5       0.50      0.40      0.45      4151
#
#     accuracy                           0.43     20000
#    macro avg       0.41      0.35      0.37     20000
# weighted avg       0.42      0.43      0.41     20000
#
# Split : 5
# Model: KmeansCF('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.29      0.02      0.04      1158
#            2       0.24      0.14      0.17      2377
#            3       0.32      0.42      0.36      5477
#            4       0.38      0.56      0.45      6820
#            5       0.39      0.12      0.18      4168
#
#     accuracy                           0.35     20000
#    macro avg       0.27      0.21      0.20     20000
# weighted avg       0.34      0.35      0.31     20000
#
# Model: CF('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.22      0.04      0.07      1158
#            2       0.26      0.14      0.18      2377
#            3       0.34      0.33      0.33      5477
#            4       0.39      0.46      0.42      6820
#            5       0.43      0.16      0.23      4168
#
#     accuracy                           0.30     20000
#    macro avg       0.27      0.19      0.21     20000
# weighted avg       0.36      0.30      0.31     20000
#
# Model: CF('item')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.03      0.00      0.00      1158
#            2       0.08      0.01      0.02      2377
#            3       0.27      0.11      0.15      5477
#            4       0.34      0.19      0.24      6820
#            5       0.22      0.07      0.10      4168
#
#     accuracy                           0.11     20000
#    macro avg       0.16      0.06      0.09     20000
# weighted avg       0.25      0.11      0.15     20000
#
# Model: simiModel('user')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.34      0.02      0.04      1158
#            2       0.22      0.12      0.16      2377
#            3       0.32      0.41      0.36      5477
#            4       0.38      0.57      0.46      6820
#            5       0.42      0.13      0.20      4168
#
#     accuracy                           0.35     20000
#    macro avg       0.28      0.21      0.20     20000
# weighted avg       0.35      0.35      0.32     20000
#
# Model: CategoricalNB()
#               precision    recall  f1-score   support
#
#            1       0.44      0.23      0.30      1158
#            2       0.31      0.13      0.18      2377
#            3       0.40      0.42      0.41      5477
#            4       0.43      0.58      0.49      6820
#            5       0.48      0.40      0.44      4168
#
#     accuracy                           0.42     20000
#    macro avg       0.41      0.35      0.36     20000
# weighted avg       0.42      0.42      0.41     20000
